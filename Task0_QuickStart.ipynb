# %% [markdown]
# # 初始化

# %%
from Packages.LLM_BenchMarker.qwen_rater import *

tester=QwenRater()

tester.rpm_test()
# Out:
# 服务初始化成功
# Batch Size: 10, RPM: 0, Average Response Time: inf seconds
# Batch Size: 10, RPM: 125, Average Response Time: inf seconds
# Batch Size: 10, RPM: 205, Average Response Time: inf seconds
# Batch Size: 10, RPM: 313, Average Response Time: inf seconds
# Batch Size: 10, RPM: 411, Average Response Time: inf seconds
# Batch Size: 10, RPM: 494, Average Response Time: inf seconds
# Batch Size: 10, RPM: 588, Average Response Time: inf seconds
# Batch Size: 10, RPM: 677, Average Response Time: inf seconds
# Batch Size: 10, RPM: 791, Average Response Time: inf seconds
# Batch Size: 10, RPM: 869, Average Response Time: inf seconds
# Batch Size: 10, RPM: 960, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1067, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1170, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1226, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1395, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1446, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1573, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1619, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1741, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1833, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1909, Average Response Time: inf seconds
# Batch Size: 10, RPM: 1994, Average Response Time: inf seconds
# Batch Size: 10, RPM: 2000, Average Response Time: inf seconds
# Batch Size: 10, RPM: 2000, Average Response Time: inf seconds
# Batch Size: 10, RPM: 2000, Average Response Time: inf seconds
# rpm_is_stable
# Final RPM: 2000.0
# 2000.0

# %%
import os
from local_packages import *                                                                                                                                                                                                                                                                                                                                               

# 初始化API
agentopener=AgentOpener(service_type='qwen', version='long')

llm=agentopener.service

embedder=QwenEmbedder()
# Out:
# 服务初始化成功

# %%
answer=llm.ask('你好')
print(answer)
# Out:
# 你好！有什么我能帮助你的吗？

# %%
vec=embedder.embed_text(answer)
print(vec)
# Out:
# [0.11480577290058136, 3.1070446968078613, -2.426426887512207, 1.8947781324386597, -1.4686617851257324, 2.1084201335906982, 1.4298882484436035, -0.3828396201133728, -0.6337856650352478, 0.46934136748313904, -1.7339192628860474, 0.6143337488174438, 4.124587535858154, -1.5994845628738403, 2.2639973163604736, 0.7724880576133728, -1.8711968660354614, -0.9201714396476746, -1.0115694999694824, 1.0012800693511963, -1.3797024488449097, -1.2798177003860474, 0.6022976636886597, 0.33791232109069824, 2.171875, -1.8079698085784912, -1.7372585535049438, -0.14479030668735504, -2.453439712524414, 1.0076225996017456, 0.8326280117034912, -4.430832386016846, 0.6824747920036316, 0.16379326581954956, 2.215961456298828, -1.0444552898406982, 2.752474069595337, 0.64727783203125, 1.1953423023223877, 0.24849310517311096, 0.9367838501930237, 1.3540364503860474, -0.7683647871017456, -0.4948459267616272, 0.34139540791511536, 0.5865261554718018, 3.0988335609436035, -0.9993253946304321, -0.5257378220558167, -1.703908920288086, -1.7014906406402588, -5.171961784362793, 1.14990234375, 0.8773790001869202, 0.510937511920929, 1.1380832195281982, 0.03787977248430252, -0.25272759795188904, -0.8193